# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mush_data = pd.read_csv('D:\\programming Python\\Stepic Machine leaning 02.2020\\training_mush.csv')

# %%
mush_data.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          2            0          3        1     5                1
# 1          2            0          4        0     5                1
# 2          2            0          3        0     2                1
# 3          0            0          3        0     5                1
# 4          2            3          3        1     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          0           9            1  ...
# 1             0          1          10            0  ...
# 2             0          0           7            0  ...
# 3             1          0           2            0  ...
# 4             0          0          10            1  ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       3                       7          0           2
# ...

# %%
y = mush_data.pop('class')

X = mush_data

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            0          3        1     5                1
# 1             2            0          4        0     5                1
# 2             2            0          3        0     2                1
# 3             0            0          3        0     5                1
# 4             2            3          3        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 6088          2            0          3        0     5                1
# 6089          3            2          2        0     2                1
# 6090          5            2          3        0     1                1
# 6091          3            2          3        0     5                1
# 6092          2            0          9        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 6088    0
# 6089    1
# 6090    1
# 6091    0
# 6092    1
# Name: class, Length: 6093, dtype: int64

# %%
clf = RandomForestClassifier(random_state=0)

# %%
params = {
    'n_estimators':range(10,51,10),
'max_depth':range(1,13,2),
'min_samples_leaf':range(1,8),
'min_samples_split':range(2,10,2)   
}

# %%
grid_search_cv_clf = GridSearchCV(clf, params, n_jobs=-1, cv=3)

# %%
grid_search_cv_clf.fit(X,y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10, 2),
#                          'n_estimators': range(10, 51, 10)})

# %%
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
best_classifier = grid_search_cv_clf.best_estimator_

# %%
feature_imp = best_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'features':list(X),'feature_imp':feature_imp})

# %%
feature_imp_df.sort_values('feature_imp',ascending=False)
# Out:
#                     features  feature_imp
# 4                       odor     0.188376
# 8                 gill-color     0.103861
# 10                stalk-root     0.103793
# 19         spore-print-color     0.083564
# 6               gill-spacing     0.080840
# 18                 ring-type     0.070726
# 3                    bruises     0.070109
# 7                  gill-size     0.068461
# 12  stalk-surface-below-ring     0.048296
# 20                population     0.043783
# 11  stalk-surface-above-ring     0.031802
# 21                   habitat     0.022611
# 2                  cap-color     0.021773
# 13    stalk-color-above-ring     0.017689
# 17               ring-number     0.013910
# 16                veil-color     0.010881
# 9                stalk-shape     0.007563
# 14    stalk-color-below-ring     0.006253
# 1                cap-surface     0.003130
# 0                  cap-shape     0.002577
# 15                 veil-type     0.000000
# ...

# %%
#Теперь у нас есть классификатор, определяющий какие грибы съедобные, а какие нет, испробуем его! Предскажите съедобность этих данных грибов и напишите в ответ число несъедобных грибов (класс равен 1).

# %%
test_mush = pd.read_csv('D:\\programming Python\\Stepic Machine leaning 02.2020\\testing_mush.csv')

# %%
test_mush
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             0            3          8        1     3                1
# 1             5            3          4        1     5                1
# 2             3            3          4        0     8                1
# 3             3            2          2        0     7                1
# 4             3            2          2        0     8                1
# ...         ...          ...        ...      ...   ...              ...
# 2026          3            3          2        0     2                1
# 2027          5            2          8        1     0                1
# 2028          5            3          3        0     2                1
# 2029          5            3          3        1     5                1
# 2030          5            3          3        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
net = pd.DataFrame(best_classifier.predict(test_mush))

# %%
net.sum()
# Out:
# 0    976
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix

# %%
test_y_mush = pd.read_csv('D:\\programming Python\\Stepic Machine leaning 02.2020\\testing_y_mush.csv')

# %%
test_y_mush.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2031 entries, 0 to 2030
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   2031 non-null   int64
# dtypes: int64(1)
# memory usage: 15.9 KB

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(test_y_mush, net)
# Out:
# array([[1055,    0],
#        [   0,  976]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(test_y_mush, net), annot=True,annot_kws={"size": 16})
